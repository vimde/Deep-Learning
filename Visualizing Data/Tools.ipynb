# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = 'data/module_5_auto.csv'

# %%
auto_df = pd.read_csv(path)

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Line Plot

# %% [markdown]
# What is a line plot and why use it?
#
# A line chart or line plot is a type of plot which displays information as a series of data points called 'markers' connected by straight line segments. It is a basic type of chart common in many fields. Use line plot when you have a continuous data set. These are best suited for trend-based visualizations of data over a period of time.

# %%
auto_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  symboling  normalized-losses         make  \
# 0           0             0          3                122  alfa-romero
# 1           1             1          3                122  alfa-romero
# 2           2             2          1                122  alfa-romero
# 3           3             3          2                164         audi
# 4           4             4          2                164         audi
#
#   aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# 0        std          two  convertible          rwd           front  ...
# 1        std          two  convertible          rwd           front  ...
# 2        std          two    hatchback          rwd           front  ...
# 3        std         four        sedan          fwd           front  ...
# 4        std         four        sedan          4wd           front  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price  \
# ...

# %%
horsepower = auto_df[['horsepower']]

# %%
horsepower.plot()

# %%
horsepower.plot(kind='line')
plt.title('Horsepower')
plt.xlabel('Index')
plt.ylabel('Values')
plt.show()

# %%
horsepower.idxmax()
# Out:
# horsepower    46
# dtype: int64

# %%
horsepower.iloc[46]
# Out:
# horsepower    262.0
# Name: 46, dtype: float64

# %%
horsepower.plot(kind='line')
plt.title('Horsepower')
plt.xlabel('Index')
plt.ylabel('Value')
plt.text(46, 262, 'Maximum horsepower')
plt.show()

# %% [markdown]
# There are many other plotting styles available other than the default Line plot, all of which can be accessed by passing kind keyword to plot(). The full list of available plots are as follows:
#
# - bar for vertical bar plots
# - barh for horizontal bar plots
# - hist for histogram
# - box for boxplot
# - kde or density for density plots
# - area for area plots
# - pie for pie plots
# - scatter for scatter plots
# - hexbin for hexbin plot

# %% [markdown]
# There are two styles/options of ploting with matplotlib. Plotting using the Artist layer and plotting using the scripting layer.

# %% [markdown]
# #### Area plots are stacked by default. And to produce a stacked area plot, each column must be either all positive or all negative values (any NaN values will defaulted to 0). To produce an unstacked plot, pass stacked=False.

# %%
horsepower.plot(kind = 'area', stacked = False, figsize= (21, 10))
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Horse power')
plt.show()

# %% [markdown]
# The unstacked plot has a default transparency (aplha value) at 0.5. We can modify this value by passing in the alpha parameter.

# %%
horsepower.plot(kind = 'area', stacked = False, figsize= (21, 10), alpha = 0.23)
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Horse power')
plt.show()

# %% [markdown]
# ## Histogram

# %% [markdown]
# A histogram is a way of representing the frequency distribution of numeric data set. The way it works is it partitions the x-axis into bins, assigns each data point in our dataset to a bin, and then counts the number of data points that have been assigned to each bin. So the y-axis is the frequency or the number of data points in each bin. Note that we can change the bin size and usually one needs to tweak it so that the distribution is displayed nicely.

# %% [markdown]
# By default, the histrogram method breaks up the dataset into 10 bins.

# %%
horsepower.plot(kind = 'hist', stacked = False, figsize= (21, 10))
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Horse power')
plt.show()

# %% [markdown]
# Notice that the x-axis labels do not match with the bin size. This can be fixed by passing in a xticks keyword that contains the list of the bin sizes, as follows:

# %%
count, bin_edges = np.histogram(horsepower)

# %%
count
# Out:
# array([44, 45, 48, 24, 14, 16,  5,  4,  0,  1], dtype=int64)

# %%
bin_edges
# Out:
# array([ 48. ,  69.4,  90.8, 112.2, 133.6, 155. , 176.4, 197.8, 219.2,
#        240.6, 262. ])

# %%
horsepower.plot(kind = 'hist', stacked = False, figsize= (21, 10), xticks=bin_edges)
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Horse power')
plt.show()

# %%
horsepower.plot(kind = 'hist', stacked = True, figsize= (21, 10), xticks=bin_edges)
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Horse power')
plt.show()

# %%
count, bin_edges = np.histogram(horsepower, 15)

# %%
count
# Out:
# array([14, 48, 27, 33, 31,  8, 10, 17,  3,  5,  1,  3,  0,  0,  1],
#       dtype=int64)

# %%
bin_edges
# Out:
# array([ 48.        ,  62.26666667,  76.53333333,  90.8       ,
#        105.06666667, 119.33333333, 133.6       , 147.86666667,
#        162.13333333, 176.4       , 190.66666667, 204.93333333,
#        219.2       , 233.46666667, 247.73333333, 262.        ])

# %%
xmin = bin_edges[0] - 10

# %%
xmax = bin_edges[-1] + 10

# %%
horsepower.plot(kind = 'hist', stacked = True, figsize= (21, 10), xticks=bin_edges, xlim= (xmin, xmax), bins=15)
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Horse power')
plt.show()

# %% [markdown]
# ## Bar Charts

# %% [markdown]
# A bar plot is a way of representing data where the length of the bars represents the magnitude/size of the feature/variable. Bar graphs usually represent numerical and categorical variables grouped in intervals.
#
# To create a bar plot, we can pass one of two arguments via kind parameter in plot():
#
# - kind=bar creates a vertical bar plot
# - kind=barh creates a horizontal bar plot

# %% [markdown]
# #### Vertical bar plot
#
# In vertical bar graphs, the x-axis is used for labelling, and the length of bars on the y-axis corresponds to the magnitude of the variable being measured. Vertical bar graphs are particuarly useful in analyzing time series data. One disadvantage is that they lack space for text labelling at the foot of each bar.

# %%
horsepower.plot(kind = 'bar', figsize=(15, 10))
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Horse power')
plt.show()

# %% [markdown]
# #### Horizontal Bar Plot

# %%
horsepower.plot(kind = 'barh', figsize=(15, 10))
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Horse power')
plt.show()

# %% [markdown]
# ## Pie Charts

# %% [markdown]
# A pie chart is a circualr graphic that displays numeric proportions by dividing a circle (or pie) into proportional slices.

# %%
auto_df['horsepower-binned'].value_counts()
# Out:
# Low       115
# Medium     62
# High       23
# Name: horsepower-binned, dtype: int64

# %%
auto_df_horsepower = auto_df.groupby('horsepower-binned', axis = 0).sum()
# Out:
#                    Unnamed: 0  Unnamed: 0.1  symboling  normalized-losses  \
# horsepower-binned
# High                     2578          2578         23               3116
# Low                     11361         11361         86              13408
# Medium                   6115          6115         60               7876
#
#                    wheel-base     length       width  height  curb-weight  \
# horsepower-binned
# High                   2359.6  20.535800   21.665278  1235.7        73613
# Low                   11185.8  93.394522  103.770833  6201.5       262160
# Medium                 6210.8  53.406055   57.523611  3322.1       173966
#
#                    engine-size  ...  stroke  compression-ratio   horsepower  \
# horsepower-binned               ...
# High                      4337  ...   75.83             197.20  4020.000000
# Low                      12065  ...  360.80            1235.21  8973.000000
# ...

# %% [markdown]
# We will pass in kind = 'pie' keyword, along with the following additional parameters:
#
# - autopct - is a string or function used to label the wedges with their numeric value. The label will be placed inside the wedge. If it is a format string, the label will be fmt%pct.
# - startangle - rotates the start of the pie chart by angle degrees counterclockwise from the x-axis.
# - shadow - Draws a shadow beneath the pie (to give a 3D feel).

# %%
auto_df_horsepower['horsepower'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow   
                            )
plt.title("Horse power proportions")
plt.show()

# %% [markdown]
# ## Box plots

# %% [markdown]
# A box plot is a way of statistically representing the distribution of the data through five main dimensions:
#
# - Minimun: Smallest number in the dataset.
# - First quartile: Middle number between the minimum and the median.
# - Second quartile (Median): Middle number of the (sorted) dataset.
# - Third quartile: Middle number between median and maximum.
# - Maximum: Highest number in the dataset.

# %%
horsepower.plot(kind='box', figsize=(12, 7))
plt.title("Horse power Box plot")
plt.ylabel('Values')
plt.plot()
# Out:
# []

# %% [markdown]
# To print the horizontal box plot, we have to pass vert = False.

# %%
horsepower.plot(kind='box', figsize=(12, 7), vert = False)
plt.title("Horse power Box plot")
plt.xlabel('Values')
plt.plot()
# Out:
# []

# %% [markdown]
# Often times we might want to plot multiple plots within the same figure. For example, we might want to perform a side by side comparison of the box plot with the line plot.

# %% [markdown]
# To visualize multiple plots together, we can create a figure (overall canvas) and divide it into subplots, each containing a plot. With subplots, we usually work with the artist layer instead of the scripting layer.
#
# Typical syntax is :
#
# - fig = plt.figure() # Create figure
# - ax = fig.add_subplot(nrows, ncols, plot_number) # Create subplots
#
# where
#
# 1. nrows and ncols are used to notionally split the figure into (nrows * ncols) sub-axes,
# 2. plot_number is used to identify the particular subplot that this function is to create within the notional grid. plot_number starts at 1, increments across rows first and has a maximum of nrows * ncols as shown below.

# %%
fig = plt.figure()
ax0 = fig.add_subplot(1,2,1) # add subplot 1 (1 row, 2 columns, first plot)
ax1 = fig.add_subplot(122) # add subplot 2 (1 row, 2 columns, second plot)


horsepower.plot(kind='line', figsize=(12, 7), ax = ax0)
ax0.set_title('Horsepower')
ax0.set_xlabel('Index')
ax0.set_ylabel('Values')

horsepower.plot(kind='box', figsize=(12, 7), ax = ax1)
ax1.set_title("Horse power Box plot")
ax1.set_ylabel('Values')

plt.show()

# %% [markdown]
# In the case when nrows, ncols, and plot_number are all less than 10, a convenience exists such that the a 3 digit number can be given instead, where the hundreds represent nrows, the tens represent ncols and the units represent plot_number. For instance,
#
# ##### subplot(211) == subplot(2, 1, 1)

# %% [markdown]
# ## Scatter Plots

# %% [markdown]
# A scatter plot (2D) is a useful method of comparing variables against each other. Scatter plots look similar to line plots in that they both map independent and dependent variables on a 2D graph. While the datapoints are connected together by a line in a line plot, they are not connected in a scatter plot. The data in a scatter plot is considered to express a trend. With further analysis using tools like regression, we can mathematically calculate this relationship and use it to predict trends outside the dataset.

# %%
auto_df.plot(kind='scatter', x='horsepower', y='price', figsize=(10, 6), color='darkblue')
plt.title('Horsepower vs Price')
plt.xlabel('Horse power')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Bubble Plots

# %% [markdown]
# A bubble plot is a variation of the scatter plot that displays three dimensions of data (x, y, z). The datapoints are replaced with bubbles, and the size of the bubble is determined by the third variable 'z', also known as the weight. In maplotlib, we can pass in an array or scalar to the keyword s to plot(), that contains the weight of each point.

# %% [markdown]
# We have to set the weights for the bubble. So let's normalize the horsepower.
#
# There are several methods of normalizations in statistics, each with its own use. In this case, we will use feature scaling to bring all values into the range [0,1]. The general formula is:
#
# **X! = (X - Xmin)/(Xmax - Xmin)**

# %%
normalized_horsepower = (auto_df.horsepower - auto_df.horsepower.min())/(auto_df.horsepower.max() - auto_df.horsepower.min())
normalized_horsepower[0:5]
# Out:
# 0    0.294393
# 1    0.294393
# 2    0.495327
# 3    0.252336
# 4    0.313084
# Name: horsepower, dtype: float64

# %%
auto_df.plot(kind='scatter',
                    x='price',
                    y='horsepower',
                    figsize=(14, 8),
                    alpha=0.5,                  # transparency
                    color='green',
                    s=normalized_horsepower * 2000 + 10,  # pass in weights 
                   )

# %% [markdown]
# The size of the bubble corresponds to the magnitude.

# %% [markdown]
# ## Regression Plots

# %% [markdown]
# It works like a scatter plot with the regression line

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
# sns.set_style('ticks') # for white background
sns.set_style('whitegrid') # for white background with grid lines
ax = sns.regplot(x = 'price', y = 'horsepower', data = auto_df, color = 'green', marker = '+', scatter_kws={'s': 50})
ax.set(xlabel='Price', ylabel='Horse Power')
ax.set_title('Price vs Horse Power')
# Out:
# Text(0.5, 1.0, 'Price vs Horse Power')
